# %% [markdown]
# # Lab 1 Analysis Example using Thicket

# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %% [markdown]
# Read in all the files

# %%
# MPI strong scaling size 65536
#tk = th.Thicket.from_caliperreader(glob("/scratch/user/noahthompson/MPI/*a65536-*.cali"))
# MPI strong scaling size 262144
#tk = th.Thicket.from_caliperreader(glob("/scratch/user/noahthompson/MPI/*a262144-*.cali"))
# MPI strong scaling size 1048576
#tk = th.Thicket.from_caliperreader(glob("/scratch/user/noahthompson/MPI/*a1048576-*.cali"))
# MPI strong scaling size 4194304
#tk = th.Thicket.from_caliperreader(glob("/scratch/user/noahthompson/MPI/*a4194304-*.cali"))
# MPI strong scaling size 16777216
#tk = th.Thicket.from_caliperreader(glob("/scratch/user/noahthompson/MPI/*a16777216-*.cali"))
# MPI strong scaling size 67108864
#tk = th.Thicket.from_caliperreader(glob("/scratch/user/noahthompson/MPI/*a67108864-*.cali"))
# MPI strong scaling size 268435456
#tk = th.Thicket.from_caliperreader(glob("/scratch/user/noahthompson/MPI/*a268435456-*.cali"))

# CUDA strong scaling size 65536
#tk2 = th.Thicket.from_caliperreader(glob("/scratch/user/noahthompson/CUDA/*v65536-*.cali"))
# CUDA strong scaling size 262144
#tk2 = th.Thicket.from_caliperreader(glob("/scratch/user/noahthompson/CUDA/*v262144-*.cali"))
# CUDA strong scaling size 1048576
#tk2 = th.Thicket.from_caliperreader(glob("/scratch/user/noahthompson/CUDA/*v1048576-*.cali"))
# CUDA strong scaling size 4194304
#tk2 = th.Thicket.from_caliperreader(glob("/scratch/user/noahthompson/CUDA/*v4194304-*.cali"))
# CUDA strong scaling size 16777216
#tk2 = th.Thicket.from_caliperreader(glob("/scratch/user/noahthompson/CUDA/*v16777216-*.cali"))
# CUDA strong scaling size 67108864
#tk2 = th.Thicket.from_caliperreader(glob("/scratch/user/noahthompson/CUDA/*v67108864-*.cali"))
# CUDA strong scaling size 268435456
#tk2 = th.Thicket.from_caliperreader(glob("/scratch/user/noahthompson/CUDA/*v268435456-*.cali"))

# MPI weak scaling/speedup Sorted
#tk = th.Thicket.from_caliperreader(glob("/scratch/user/noahthompson/MPI/*iSorted.cali"))
# MPI weak scaling Random
#tk = th.Thicket.from_caliperreader(glob("/scratch/user/noahthompson/MPI/*iRandom.cali"))
# MPI weak scaling ReverseSorted
#tk = th.Thicket.from_caliperreader(glob("/scratch/user/noahthompson/MPI/*iReverseSorted.cali"))
# MPI weak scaling 1%Perturbed
#tk = th.Thicket.from_caliperreader(glob("/scratch/user/noahthompson/MPI/*iPerturbed.cali"))

# CUDA weak scaling/speedup Sorted
#tk2 = th.Thicket.from_caliperreader(glob("/scratch/user/noahthompson/CUDA/*iSorted.cali"))
# CUDA weak scaling Random
#tk2 = th.Thicket.from_caliperreader(glob("/scratch/user/noahthompson/CUDA/*iRandom.cali"))
# CUDA weak scaling ReverseSorted
#tk2 = th.Thicket.from_caliperreader(glob("/scratch/user/noahthompson/CUDA/*iReverseSorted.cali"))
# CUDA weak scaling 1%Perturbed
#tk2 = th.Thicket.from_caliperreader(glob("/scratch/user/noahthompson/CUDA/*iPerturbed.cali"))

# algorithm comparison MPI
tk = th.Thicket.from_caliperreader(glob("/scratch/user/noahthompson/MPI/Compare/*.cali"))

# algorithm comparison CUDA
tk2 = th.Thicket.from_caliperreader(glob("/scratch/user/noahthompson/CUDA/Compare/*.cali"))

# %%
# Performance data
tk2.dataframe
# Out:
#                                                               nid  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              1664755700    1
#                                                   2164552360    1
#                                                   2320761405    1
#                                                   3323195907    1
#                                                   3765589691    1
# {'name': 'whole_computation', 'type': 'function'} 1664755700    2
#                                                   2164552360    2
#                                                   2320761405    2
#                                                   3323195907    2
#                                                   3765589691    2
# {'name': 'correctness_check', 'type': 'function'} 1664755700   11
#                                                   2164552360   11
# ...

# %%
tk.dataframe = tk.dataframe.drop(["nid", "spot.channel", "Variance time/rank", "Min time/rank", "Max time/rank", "Total time"], axis = 1)
tk2.dataframe = tk2.dataframe.drop(["nid", "spot.channel", "Min time/rank", "Max time/rank", "Total time"], axis = 1)

# %% [markdown]
# Groupby matrix size argument, available in the metadata (tk.metadata) to organize our performance data into 3 groupings.

# %%
#print(tk.dataframe.columns)

# %%
#tk2.metadata

# %%
tk.statsframe.dataframe["time"] = 1
print(tk.tree())
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2023.3.0
#
# 1.000 main
# ├─ 1.000 comm
# │  ├─ 1.000 comm_large
# │  │  ├─ 1.000 MPI_Recv
# │  │  └─ 1.000 MPI_Send
# │  └─ 1.000 comm_small
# │     ├─ 1.000 MPI_Recv
# │     └─ 1.000 MPI_Send
# ├─ 1.000 comp
# │  └─ 1.000 comp_large
# ├─ 1.000 correctness_check
# └─ 1.000 data_init
# 1.000 whole_computation
# ├─ 1.000 comm
# │  ├─ 1.000 comm_large
# │  └─ 1.000 comm_small
# ├─ 1.000 comp
# │  ├─ 1.000 comp_large
# │  └─ 1.000 comp_small
# ├─ 1.000 correctness_check
# └─ 1.000 data_init
#
# Legend (Metric: time Min: 1.00 Max: 1.00)
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
# strong
#gb = tk.groupby("InputType")
#gb2 = tk2.groupby("InputType")

# weak
#gb = tk.groupby("InputSize")
#gb2 = tk2.groupby("InputSize")

# compare
gb = tk.groupby("Algorithm")
gb2 = tk2.groupby("Algorithm")
# Out:
# 2  thickets created...
# {'MergeSort': <thicket.thicket.Thicket object at 0x2b97328aa8e0>, 'SampleSort': <thicket.thicket.Thicket object at 0x2b97328d2c10>}
# 1  thickets created...
# {'SampleSort': <thicket.thicket.Thicket object at 0x2b973278a250>}

# %% [markdown]
# Compose these 3 groups column-wise to get a holistic view of the data

# %%
#i = 0
#for key in list(gb.keys()):
#    print(i)
#    print(gb[key].profile_mapping)
#    print(gb[key].metadata["num_procs"])
#    i += 1

# %%
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
    metadata_key="num_procs"
)
ctk2 = th.Thicket.concat_thickets(
    thickets=list(gb2.values()),
    headers=list(gb2.keys()),
    axis="columns",
    metadata_key="num_threads"
)

# %%
#ctk.metadata

# %%
ctk2.dataframe
# Out:
#                                                                  SampleSort  \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64               0.646685
#                                                   128              0.816686
#                                                   256              0.824211
#                                                   512              1.252764
#                                                   1024             0.649530
# {'name': 'whole_computation', 'type': 'function'} 64               0.646220
#                                                   128              0.816217
#                                                   256              0.823737
#                                                   512              1.252272
# ...

# %% [markdown]
# Perform pandas operations to get the table in a desirable format for plotting

# %%
# Drop unwanted columns
ctk.dataframe = ctk.dataframe.reset_index().drop([("node","")], axis=1)
# Rename index to remove tuple
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("Avg time/rank", ""): "Avg time/rank", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"])
#ctk.dataframe.columns = ctk.dataframe.columns.droplevel(1)

ctk2.dataframe = ctk2.dataframe.reset_index().drop([("node","")], axis=1)
# Rename index to remove tuple
ctk2.dataframe = ctk2.dataframe.rename({("name", ""): "name", ("Avg time/rank", ""): "Avg time/rank", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])
#ctk.dataframe.columns = ctk.dataframe.columns.droplevel(1)

# %%
ctk2.dataframe
# Out:
#                                  SampleSort
#                               Avg time/rank
# name              num_threads
# main              64               0.646685
#                   128              0.816686
#                   256              0.824211
#                   512              1.252764
#                   1024             0.649530
# whole_computation 64               0.646220
#                   128              0.816217
#                   256              0.823737
#                   512              1.252272
#                   1024             0.649064
# correctness_check 64               0.010882
#                   128              0.011319
#                   256              0.010925
#                   512              0.012206
#                   1024             0.014397
# data_init         64               0.016669
#                   128              0.016760
#                   256              0.016873
#                   512              0.017817
# ...

# %%
# Define common variables
function_names = set({"whole_computation", "comp_large", "comm"})
num_procs = sorted(list(set(ctk.dataframe.index.get_level_values("num_procs"))))
input_sizes = sorted(list(set(ctk.dataframe.columns.get_level_values(0))))

num_threads = sorted(list(set(ctk2.dataframe.index.get_level_values("num_threads"))))
input_sizes2 = sorted(list(set(ctk2.dataframe.columns.get_level_values(0))))

# %% [markdown]
# # Plotting

# %% [markdown]
# ### Option 1
# Use `pandas.DataFrame.plot` to automatically interface with matplotlib

# %%
def plot_pandas(df, title, xlabel, ylabel, loglog):
    plot = df.plot(kind="line", 
        marker='o', 
        title=title, 
        xlabel=xlabel,
        ylabel=ylabel, 
        grid=True,
        loglog=loglog
    )
    return plot

# %%
# strong/weak scaling

for name in function_names:
    plot_pandas(
        df=ctk.dataframe.loc[name].droplevel(1, axis = 1),
        title=name,
        xlabel="Processes",
        ylabel="Avg Time (seconds)",
        loglog=True,
    )

# speedup

#for name in function_names:
#    plot_pandas(
#        df=(ctk.dataframe.iloc[0]/ctk.dataframe).loc[name].droplevel(1, axis = 1),
#        title=name,
#        xlabel="Processes",
#        ylabel="Speedup",
#        loglog=True
#    )

# %%
# strong/weak scaling

for name in function_names:
    plot_pandas(
        df=ctk2.dataframe.loc[name].droplevel(1, axis = 1),
        title=name,
        xlabel="Threads",
        ylabel="Avg Time (seconds)",
        loglog=True
    )

#speedup

#for name in function_names:
#    plot_pandas(
#        df=(ctk2.dataframe.iloc[0]/ctk2.dataframe).loc[name].droplevel(1, axis = 1),
#        title=name,
#        xlabel="Threads",
#        ylabel="Speedup",
#        loglog=True
#    )

# %% [markdown]
# ### Option 2
# Use `matplotlib.pyplot` directly for more fine-grained control. Specifically for our case we can change the x axis scaling from base 10 to base 2.

# %% [markdown]
# # Examples

# %% [markdown]
# ## time

# %% [markdown]
# ## Speedup
